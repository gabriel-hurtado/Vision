# %% [markdown]
# ## 1 - 1

# %%
import cv2
import numpy as np
import sys
import math
import random
from matplotlib import pyplot as plt

# %%
def findM(UVs,XYZs,verbose=False):
    n=len(UVs)
    As=np.zeros((2*n,12))
    for i in range(0,n):
        for j in range(0,2):
            curr2d=-XYZs[i,:]*UVs[i,:][j]#is it right ?
            if(j==1):
                rangeJ=slice(4,8)
            else:
                rangeJ=slice(0,4)
            As[2*i+j,rangeJ]=XYZs[i,:]
            As[2*i+j,slice(8,12)]=curr2d
            if(verbose):
                print("step "+str(2*i+j))
                print("XYZ= ")
                print(XYZs[i,:])
                print("UV")
                print(UVs[i,:][j])
                print(curr2d)            
                print("As=")
                print(As[2*i+j,:])
   
    doted=np.dot(As.T,As)
    _, _,vectors = np.linalg.svd(doted)
    m=vectors[-1]
    m=m.reshape(3,4)
    return m

# %%
UVs=np.loadtxt('pts2d-norm-pic_a.txt')
XYZs=np.loadtxt('pts3d-norm.txt')
ones=np.ones(len(XYZs))
ones=ones[:,None]
XYZsNm=np.concatenate((XYZs,ones),axis=1)

# %%
m=findM(UVs,XYZsNm)
print("m = \n"+str(m))
# Out:
# m =
# [[ 0.45827554 -0.29474237 -0.01395746  0.0040258 ]
#  [-0.05085589 -0.0545847  -0.54105993 -0.05237592]
#  [ 0.10900958  0.17834548 -0.04426782  0.5968205 ]]

# %%
def project(m,XYZsNm,UVs):#retrurns the projection and residual     
    UVsHom=np.dot(m,XYZsNm.T)
    UVsComp=np.zeros((len(UVs),2))
    for i in range(len(UVs)):
        for j in range(0,2):
            UVsComp[i,j]=UVsHom[j,i]/UVsHom[2,i]

    dist = np.linalg.norm(UVs-UVsComp)
    return UVsComp,dist

UVsComp,dist=project(m,XYZsNm,UVs)
print("Last coordianet computed "+str(UVsComp[-1]))
print("Distance between computed and true = "+str(dist))
# Out:
# Last coordianet computed [ 0.14190608 -0.45184301]
# Distance between computed and true = 0.0129913733751

# %% [markdown]
# ## 1 - 2

# %%
UVs=np.loadtxt('pts2d-pic_b.txt')
XYZs=np.loadtxt('pts3d.txt')
n=len(XYZs)
ones=np.ones(n)
ones=ones[:,None]
XYZsNm=np.concatenate((XYZs,ones),axis=1)

distMin=math.inf
ks=[8,12,16]
for k in ks:
    for i in range(0,10):
        selected=random.sample(range(0,n),k)
        UVsK=UVs[selected]
        XYZsNmK=XYZsNm[selected]
        m=findM(UVsK,XYZsNmK)
        while True:
            others=random.sample(range(0,n),4)
            if(not(any(x in selected for x in others))):
                break
        UVsCompK,distK=project(m,XYZsNmK,UVsK)
        if(distK<distMin):
            distMin=distK
            bestM=m
        print("Residual at try "+str(i)+" for k = "+str(k)+" is "+str(distK))

print("Best m found with residual of "+str(distMin)+" is \n"+str(bestM))
# Out:
# Residual at try 0 for k = 8 is 0.620343273037
# Residual at try 1 for k = 8 is 1.98772547484
# Residual at try 2 for k = 8 is 1.40575231798
# Residual at try 3 for k = 8 is 0.724017158988
# Residual at try 4 for k = 8 is 1.68546356799
# Residual at try 5 for k = 8 is 1.99036830544
# Residual at try 6 for k = 8 is 0.51612530752
# Residual at try 7 for k = 8 is 1.43969760694
# Residual at try 8 for k = 8 is 1.52103096371
# Residual at try 9 for k = 8 is 0.741618650283
# Residual at try 0 for k = 12 is 2.25544785183
# Residual at try 1 for k = 12 is 2.52035813041
# Residual at try 2 for k = 12 is 2.35626440995
# Residual at try 3 for k = 12 is 2.84889456106
# Residual at try 4 for k = 12 is 2.75052832591
# Residual at try 5 for k = 12 is 2.62098724658
# Residual at try 6 for k = 12 is 2.09901918134
# Residual at try 7 for k = 12 is 2.45733388127
# Residual at try 8 for k = 12 is 2.698957181
# Residual at try 9 for k = 12 is 2.14712564846
# Residual at try 0 for k = 16 is 3.32801177517
# Residual at try 1 for k = 16 is 3.48997308051
# Residual at try 2 for k = 16 is 3.48882163819
# Residual at try 3 for k = 16 is 3.34971272828
# Residual at try 4 for k = 16 is 2.95696021515
# Residual at try 5 for k = 16 is 3.09314730294
# Residual at try 6 for k = 16 is 3.25476590887
# Residual at try 7 for k = 16 is 3.29133233793
# Residual at try 8 for k = 16 is 2.87340780114
# Residual at try 9 for k = 16 is 3.41267144151
# Best m found with residual of 0.51612530752 is
# [[  7.19626634e-03  -4.34739233e-03  -7.35548619e-04  -8.21336269e-01]
#  [  1.53781807e-03   1.08316534e-03  -7.47897291e-03  -5.70318892e-01]
#  [  7.77910218e-06   3.89898068e-06  -1.04767148e-06  -3.52052425e-03]]

# %% [markdown]
# We notice that the residual seem to be smaller when choosing randomly points in the set, and picking the best m for different random selections. Computing m with a bigger set increases the probability of fitting noise.

# %% [markdown]
# ## 1 - 3

# %%
def findC(bestM):
    Q=bestM[:,0:3]
    m4=bestM[:,3]
    Qinv=np.linalg.inv(Q)
    C=np.dot(-Qinv,m4.T)
    return C
C=findC(m)
print("Debug output = "+str(C))
C=findC(bestM)
print("Output for previous best m = "+str(C))
# Out:
# Debug output = [-1.51267725 -2.35168754  0.28262819]
# Output for previous best m = [ 302.75639627  307.07327412   30.46895558]

# %% [markdown]
# # 2

# %% [markdown]
# ## 2 - 1

# %%
UVsA=np.loadtxt('pts2d-pic_a.txt')
UVsB=np.loadtxt('pts2d-pic_b.txt')
ones=np.ones(len(UVsA))
ones=ones[:,None]
UVsA=np.concatenate((UVsA,ones),axis=1)
UVsB=np.concatenate((UVsB,ones),axis=1)

# %%
def findF(UVsA,UVsB,verbose=False):
    n=len(UVs)
    As=np.zeros((n,9))
    for i in range(0,n):
        currA=UVsA[i,:]
        currB=UVsB[i,:]
        for j in range(0,3):
            rangeCurr=slice(0+j*3,3+j*3)
            As[i,rangeCurr]=currB*currA[j]
        if(verbose):
            print("UV A")
            print(currA)
            print("UV B")
            print(currB)
            print("Line")
            print(As[i,:])
    doted=np.dot(As.T,As)
    _, _,vectors = np.linalg.svd(doted)
    m=vectors[-1]
    m=m.reshape(3,3)
    if(verbose):
        print(As)
    return m

# %%
f_=findF(UVsA,UVsB)
print("f_ = \n"+str(f_))
# Out:
# f_ =
# [[ -6.60698417e-07   8.82396296e-06  -9.07382302e-04]
#  [  7.91031621e-06   1.21382933e-06  -2.64234650e-02]
#  [ -1.88600198e-03   1.72332901e-02   9.99500092e-01]]

# %% [markdown]
# ## 2 - 2

# %%
u, e, vt = np.linalg.svd(f_)
e[-1]=0
f=np.dot(np.dot(u,np.diag(e)), vt)
print("f = \n"+str(f))
# Out:
# f =
# [[ -5.36264198e-07   8.83539184e-06  -9.07382264e-04]
#  [  7.90364771e-06   1.21321685e-06  -2.64234650e-02]
#  [ -1.88600204e-03   1.72332901e-02   9.99500092e-01]]

# %% [markdown]
# ## 2 - 3

# %%
lineB=np.dot(UVsA,f)
lineA=np.dot(UVsB,f.T)
print(lineB)
# Out:
# [[ -6.66533925e-04   2.52680633e-02  -5.45361781e+00]
#  [ -3.04620916e-04   1.78594950e-02  -4.40348074e+00]
#  [ -4.73774775e-04   1.98578496e-02  -4.45091572e+00]
#  [  3.81433635e-04   2.54824335e-02  -8.97338295e+00]
#  [  1.01382740e-04   2.41820485e-02  -7.65638612e+00]
#  [ -1.38003227e-03   2.57203564e-02  -3.23836490e+00]
#  [  2.52188835e-03   2.21547346e-02  -1.50222582e+01]
#  [ -4.19316130e-04   2.11949477e-02  -5.03531458e+00]
#  [  5.91724191e-04   2.04405370e-02  -8.14000086e+00]
#  [  1.81190355e-03   2.47834879e-02  -1.34776055e+01]
#  [  1.36283344e-03   1.98276508e-02  -1.04965543e+01]
#  [  1.14804713e-03   2.36292957e-02  -1.09395756e+01]
#  [  6.23865380e-04   2.34596563e-02  -9.16012962e+00]
#  [  5.16927834e-04   2.14100036e-02  -8.18696598e+00]
#  [  1.17307091e-03   2.13769565e-02  -1.03400794e+01]
#  [  4.88125213e-04   2.42503315e-02  -8.95204329e+00]
#  [  1.16127310e-03   2.15713352e-02  -1.03600418e+01]
#  [ -3.18087181e-04   2.21557636e-02  -5.65996640e+00]
#  [  1.64356288e-04   2.39331014e-02  -7.78861283e+00]
#  [ -7.30850966e-04   2.27790675e-02  -4.48793198e+00]]

# %%
def drawlines(img,lines,pts1,pts2):
    r,c,_ = img.shape
    for r in lines:
        x0,y0 = map(int, [0, -r[2]/r[1] ])
        x1,y1 = map(int, [c, -(r[2]+r[0]*c)/r[1] ])
        img = cv2.line(img, (x0,y0), (x1,y1),1)
    return img

# %%
imgA = cv2.imread('pic_a.jpg')  
imgB = cv2.imread('pic_b.jpg') 

imgBLines = drawlines(imgB,lineB,UVsB,UVsA)
imgALines = drawlines(imgA,lineA,UVsA,UVsB)

b,g,r = cv2.split(imgALines)       # get b,g,r
imgALines = cv2.merge([r,g,b])     # switch it to rgb
plt.figure(figsize=(20,30))
plt.imshow(imgALines)
plt.title('Left with lines'), plt.xticks([]), plt.yticks([])
plt.show()

b,g,r = cv2.split(imgBLines)       # get b,g,r
imgBLines = cv2.merge([r,g,b])     # switch it to rgb
plt.figure(figsize=(20,30))
plt.imshow(imgBLines)
plt.title('Right with lines'), plt.xticks([]), plt.yticks([])
plt.show()
