# %%
# %matplotlib inline
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython import display

# %%
def plotVideo(title):
    vc = cv2.VideoCapture(title)
    is_capturing, frame = vc.read()
    preview = plt.imshow(frame) 

    while is_capturing:


            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    
            preview.set_data(frame)
            plt.draw()
            plt.xticks([]), plt.yticks([])
            display.display(plt.gcf())
            is_capturing, frame = vc.read()
            display.clear_output(wait=True)

# %%
def getFrame(n,title):
    video = cv2.VideoCapture(title)
    i=0
    while i<=n:
        is_capturing, frame = video.read()
        if(not is_capturing):
            print("Not enough frames in the video for frame "+str(i))
            return -1
        else:
            if i==n:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) 
                return frame
        i+=1
    print("Unexpected error")
    return -1

# %%
from numpy.random import uniform

def create_uniform_particles(x_range, y_range,  N):
    particles = np.empty((N, 3))
    particlesX = uniform(x_range[0], x_range[1], size=N)
    particlesY = uniform(y_range[0], y_range[1], size=N)
    return particlesX, particlesY

# %%
def plotImage(image,title):
    plt.imshow(image)
    plt.title(title), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def plotImageParticles(image,title,pX,pY,yHalfWin,xHalfWin,weight):
    fig,ax=plt.subplots(1)
    ax.imshow(image)
    ax.scatter(pX,pY,s=1)
    plt.title(title), plt.xticks([]), plt.yticks([])
    Xmean=np.average(pX,weights=weight)
    Ymean=np.average(pY,weights=weight)
    
    dist=[]
    for i in range(0,len(pX)):
        dist.append(np.linalg.norm(pX[i]-Xmean)+np.linalg.norm(pY[i]-Ymean))
        
    
    rad=np.sum(dist*weight)
    
    ax.add_patch(patches.Rectangle((Xmean-xHalfWin,Ymean-yHalfWin),
                                       2*xHalfWin,
                                       2*yHalfWin,
                                       fill=False))
    ax.add_patch(patches.Circle((Xmean,Ymean),rad,fill=False))
    plt.show()

# %%
#plotVideo('pres_debate.avi')

# %%
frame0=getFrame(0,'pres_debate.avi')
plotImage(frame0,"Frame 0 of pres debate")

# %%
boxPres=np.loadtxt('pres_debate.txt')
topLeftPres=boxPres[0:2]
sizePres=boxPres[2:4]

# %%
def predict(particlesX,particlesY, std):
    N = len(particlesX)
    particlesX += np.random.normal(0,std,N)
    particlesY += np.random.normal(0,std,N)
    return particlesX, particlesY

# %%
def particleFilter(topLeft,sizeBox,video,N,std=50,sMSE=10):
    
    xHalfWin=sizeBox[0]//2
    yHalfWin=sizeBox[1]//2
    
    x_left=int(topLeft[0])
    x_right=int(topLeft[0]+2*xHalfWin)
    y_top=int(topLeft[1])
    y_bottom=int(topLeft[1]+2*yHalfWin)
    
    x_rangeInit=[x_left,x_right]
    y_rangeInit=[y_top,y_bottom]
    
    frame0=getFrame(0,video)
    particlesX, particlesY=create_uniform_particles(x_rangeInit, y_rangeInit,  N)
    
    weights=np.ones(N)
    weights=weights/N
    plotImageParticles(frame0,"Frame 0 of pres debate",particlesX, particlesY,yHalfWin,xHalfWin,weights)
    template= getWindow(frame0,y_top,y_bottom,x_left,x_right)
    
    plotImage(template,"Template")
    
    
    vc = cv2.VideoCapture(video)
    is_capturing, frame = vc.read()

    j=0
    while is_capturing:
            
            
            
        frameI = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        particlesX, particlesY = predict(particlesX,particlesY, std)
        

        probList=[]
        #maxi=0
        for i,x in enumerate(particlesX):
            y=particlesY[i]
            part=getWindow(frameI,int(y-yHalfWin),int(y+yHalfWin),int(x-xHalfWin),int(x+xHalfWin))
            probList.append(getProb(mse(part,template),sMSE))
            #if(probList[i]>maxi):
            #    maxi=probList[i]
            #    bestPart=part

        probList=np.asarray(probList)

        probList=probList/probList.sum(0)
        
        #maxi=np.argmax(probList)
        #plotImage(bestPart,"Template")
        
        
        plotImageParticles(frameI,"Frame "+str(j)+" of pres debate with preds",particlesX, particlesY,yHalfWin,xHalfWin,probList)
        display.clear_output(wait=True)
        
        particlesX,particlesY=resampleDiffuse(particlesX,particlesY,probList)

        is_capturing, frame = vc.read()
        j+=1

# %%
def getWindow(image,y_top,y_bottom,x_left,x_right):
    template = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    template=template[y_top:y_bottom,x_left:x_right]
    return template

# %%
def mse(imageA, imageB):
    try:
        err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
        err /= float(imageA.shape[0] * imageA.shape[1])
        return err
    except:
        return 9999999999

# %%
def getProb(mse,s=10):
    return np.exp(-mse/(2*s**2))

# %%
def resampleDiffuse(particlesX,particlesY, weights, noiseMax=50):
    N = len(weights)
    indexes=np.random.choice(range(N),N,p=weights)
            
    particlesX[:] = particlesX[indexes]
    particlesY[:] = particlesY[indexes]
    
    particlesX=particlesX+np.random.normal(scale=noiseMax,size=N)
   
    
    particlesY=particlesY+np.random.normal(scale=noiseMax,size=N)
    return particlesX,particlesY

# %%
particleFilter(topLeftPres,sizePres,'pres_debate.avi',100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-686-008b49f6ed8f> in <module>()
# ----> 1 particleFilter(topLeftPres,sizePres,'pres_debate.avi',100)
#
# <ipython-input-681-63115f4ed576> in particleFilter(topLeft, sizeBox, video, N, std, sMSE)
#      59         particlesY[particlesY>h]=h
#      60
# ---> 61         plotImageParticles(frameI,"Frame "+str(j)+" of pres debate with preds",particlesX, particlesY,yHalfWin,xHalfWin,probList)
#      62         display.clear_output(wait=True)
#      63
#
# <ipython-input-620-41ad196b06d0> in plotImageParticles(image, title, pX, pY, yHalfWin, xHalfWin, weight)
#       1 def plotImageParticles(image,title,pX,pY,yHalfWin,xHalfWin,weight):
# ----> 2     fig,ax=plt.subplots(1)
#       3     ax.imshow(image)
#       4     ax.scatter(pX,pY,s=1)
#       5     plt.title(title), plt.xticks([]), plt.yticks([])
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1174     subplot
#    1175     """
# -> 1176     fig = figure(**fig_kw)
#    1177     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1178                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     537                                         frameon=frameon,
#     538                                         FigureClass=FigureClass,
# --> 539                                         **kwargs)
#     540
#     541         if figLabel:
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#     168         from matplotlib.figure import Figure
#     169         fig_cls = kwargs.pop('FigureClass', Figure)
# --> 170         fig = fig_cls(*args, **kwargs)
#     171         return cls.new_figure_manager_given_figure(num, fig)
#     172
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout)
#     338         self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#     339
# --> 340         self.dpi_scale_trans = Affine2D().scale(dpi, dpi)
#     341         # do not use property as it will trigger
#     342         self._dpi = dpi
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2071         scale_mtx = np.array(
#    2072             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2073         self._mtx = np.dot(scale_mtx, self._mtx)
#    2074         self.invalidate()
#    2075         return self
#
# KeyboardInterrupt:

# %%
particleFilter([270,140],[200,200],'pres_debate.avi',100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-691-d791ded46551> in <module>()
# ----> 1 particleFilter([270,140],[200,200],'pres_debate.avi',100)
#
# <ipython-input-687-63115f4ed576> in particleFilter(topLeft, sizeBox, video, N, std, sMSE)
#      59         particlesY[particlesY>h]=h
#      60
# ---> 61         plotImageParticles(frameI,"Frame "+str(j)+" of pres debate with preds",particlesX, particlesY,yHalfWin,xHalfWin,probList)
#      62         display.clear_output(wait=True)
#      63
#
# <ipython-input-620-41ad196b06d0> in plotImageParticles(image, title, pX, pY, yHalfWin, xHalfWin, weight)
#       1 def plotImageParticles(image,title,pX,pY,yHalfWin,xHalfWin,weight):
# ----> 2     fig,ax=plt.subplots(1)
#       3     ax.imshow(image)
#       4     ax.scatter(pX,pY,s=1)
#       5     plt.title(title), plt.xticks([]), plt.yticks([])
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1177     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1178                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1179                        gridspec_kw=gridspec_kw)
#    1180     return fig, axs
#    1181
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1181                 subplot_kw["sharex"] = shared_with[sharex]
#    1182                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1183                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1184
#    1185         # turn off redundant tick labeling
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1072                     self._axstack.remove(ax)
#    1073
# -> 1074             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1075
#    1076         self._axstack.add(key, a)
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     517
#     518         # this call may differ for non-sep axes, e.g., polar
# --> 519         self._init_axis()
#     520         if axisbg is not None and facecolor is not None:
#     521             raise TypeError('Both axisbg and facecolor are not None. '
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _init_axis(self)
#     613         self.yaxis = maxis.YAxis(self)
#     614         self.spines['left'].register_axis(self.yaxis)
# --> 615         self.spines['right'].register_axis(self.yaxis)
#     616         self._update_transScale()
#     617
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\spines.py in register_axis(self, axis)
#     174         self.axis = axis
#     175         if self.axis is not None:
# --> 176             self.axis.cla()
#     177         self.stale = True
#     178
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     771         self._set_artist_props(self.label)
#     772
# --> 773         self.reset_ticks()
#     774
#     775         self.converter = None
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     786
#     787         self.majorTicks.extend([self._get_tick(major=True)])
# --> 788         self.minorTicks.extend([self._get_tick(major=False)])
#     789         self._lastNumMajorTicks = 1
#     790         self._lastNumMinorTicks = 1
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2095         else:
#    2096             tick_kw = self._minor_tick_kw
# -> 2097         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2098
#    2099     def _get_label(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation)
#     152         self.apply_tickdir(tickdir)
#     153
# --> 154         self.tick1line = self._get_tick1line()
#     155         self.tick2line = self._get_tick2line()
#     156         self.gridline = self._get_gridline()
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     566                           markersize=self._size,
#     567                           markeredgewidth=self._width,
# --> 568                           zorder=self._zorder)
#     569         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     570         self._set_artist_props(l)
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     400         self._color = None
#     401         self.set_color(color)
# --> 402         self._marker = MarkerStyle(marker, fillstyle)
#     403
#     404         self._markevery = None
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     187         self._marker_function = None
#     188         self.set_fillstyle(fillstyle)
# --> 189         self.set_marker(marker)
#     190
#     191     def __getstate__(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     273
#     274         self._marker = marker
# --> 275         self._recache()
#     276
#     277     def get_path(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     209         self._capstyle = 'butt'
#     210         self._filled = True
# --> 211         self._marker_function()
#     212
#     213     if six.PY3:
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     701
#     702     def _set_tickleft(self):
# --> 703         self._transform = Affine2D().scale(-1.0, 1.0)
#     704         self._snap_threshold = 1.0
#     705         self._filled = False
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2071         scale_mtx = np.array(
#    2072             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2073         self._mtx = np.dot(scale_mtx, self._mtx)
#    2074         self.invalidate()
#    2075         return self
#
# KeyboardInterrupt:

# %%
particleFilter(topLeftPres,sizePres,'pres_debate.avi',100,sMSE=20)

# %%
particleFilter(topLeftPres,sizePres,'pres_debate.avi',50,sMSE=5)

# %%
particleFilter(topLeftPres,sizePres,'noisy_debate.avi',50,sMSE=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-704-87398346f3b8> in <module>()
# ----> 1 particleFilter(topLeftPres,sizePres,'noisy_debate.avi',50,sMSE=10)
#
# <ipython-input-698-e56dd32f7751> in particleFilter(topLeft, sizeBox, video, N, std, sMSE)
#      59         particlesY[particlesY>h]=h
#      60
# ---> 61         plotImageParticles(frameI,"Frame "+str(j)+" of pres debate with preds",particlesX, particlesY,yHalfWin,xHalfWin,probList)
#      62         display.clear_output(wait=True)
#      63
#
# <ipython-input-620-41ad196b06d0> in plotImageParticles(image, title, pX, pY, yHalfWin, xHalfWin, weight)
#       1 def plotImageParticles(image,title,pX,pY,yHalfWin,xHalfWin,weight):
# ----> 2     fig,ax=plt.subplots(1)
#       3     ax.imshow(image)
#       4     ax.scatter(pX,pY,s=1)
#       5     plt.title(title), plt.xticks([]), plt.yticks([])
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1177     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1178                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1179                        gridspec_kw=gridspec_kw)
#    1180     return fig, axs
#    1181
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1181                 subplot_kw["sharex"] = shared_with[sharex]
#    1182                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1183                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1184
#    1185         # turn off redundant tick labeling
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1072                     self._axstack.remove(ax)
#    1073
# -> 1074             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1075
#    1076         self._axstack.add(key, a)
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     539
#     540         self._connected = {}  # a dict from events to (id, func)
# --> 541         self.cla()
#     542         # funcs used to format x and y - fall back on major formatters
#     543         self.fmt_xdata = None
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     980         self.yaxis.cla()
#     981         for name, spine in six.iteritems(self.spines):
# --> 982             spine.cla()
#     983
#     984         self.ignore_existing_data_limits = True
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\spines.py in cla(self)
#     181         self._position = None  # clear position
#     182         if self.axis is not None:
# --> 183             self.axis.cla()
#     184
#     185     def is_frame_like(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     771         self._set_artist_props(self.label)
#     772
# --> 773         self.reset_ticks()
#     774
#     775         self.converter = None
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     786
#     787         self.majorTicks.extend([self._get_tick(major=True)])
# --> 788         self.minorTicks.extend([self._get_tick(major=False)])
#     789         self._lastNumMajorTicks = 1
#     790         self._lastNumMinorTicks = 1
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2095         else:
#    2096             tick_kw = self._minor_tick_kw
# -> 2097         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2098
#    2099     def _get_label(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation)
#     152         self.apply_tickdir(tickdir)
#     153
# --> 154         self.tick1line = self._get_tick1line()
#     155         self.tick2line = self._get_tick2line()
#     156         self.gridline = self._get_gridline()
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     566                           markersize=self._size,
#     567                           markeredgewidth=self._width,
# --> 568                           zorder=self._zorder)
#     569         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     570         self._set_artist_props(l)
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     400         self._color = None
#     401         self.set_color(color)
# --> 402         self._marker = MarkerStyle(marker, fillstyle)
#     403
#     404         self._markevery = None
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     187         self._marker_function = None
#     188         self.set_fillstyle(fillstyle)
# --> 189         self.set_marker(marker)
#     190
#     191     def __getstate__(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     273
#     274         self._marker = marker
# --> 275         self._recache()
#     276
#     277     def get_path(self):
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     209         self._capstyle = 'butt'
#     210         self._filled = True
# --> 211         self._marker_function()
#     212
#     213     if six.PY3:
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     701
#     702     def _set_tickleft(self):
# --> 703         self._transform = Affine2D().scale(-1.0, 1.0)
#     704         self._snap_threshold = 1.0
#     705         self._filled = False
#
# D:\Users\Gabriel\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2071         scale_mtx = np.array(
#    2072             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2073         self._mtx = np.dot(scale_mtx, self._mtx)
#    2074         self.invalidate()
#    2075         return self
#
# KeyboardInterrupt:

# %%
def particleFilterDinamyc(topLeft,sizeBox,video,N,std=50,sMSE=10,alpha=0.95):
    
    xHalfWin=sizeBox[0]//2
    yHalfWin=sizeBox[1]//2
    
    x_left=int(topLeft[0])
    x_right=int(topLeft[0]+2*xHalfWin)
    y_top=int(topLeft[1])
    y_bottom=int(topLeft[1]+2*yHalfWin)
    
    x_rangeInit=[x_left,x_right]
    y_rangeInit=[y_top,y_bottom]
    
    frame0=getFrame(0,video)
    particlesX, particlesY=create_uniform_particles(x_rangeInit, y_rangeInit,  N)
    
    weights=np.ones(N)
    weights=weights/N
    plotImageParticles(frame0,"Frame 0 of pres debate",particlesX, particlesY,yHalfWin,xHalfWin,weights)
    template= getWindow(frame0,y_top,y_bottom,x_left,x_right)
    
    plotImage(template,"Template")
    
    
    vc = cv2.VideoCapture(video)
    is_capturing, frame = vc.read()

    j=0
    while is_capturing:
            
            
            
        frameI = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        particlesX, particlesY = predict(particlesX,particlesY, std)
        

        probList=[]
        maxi=0
        for i,x in enumerate(particlesX):
            y=particlesY[i]
            part=getWindow(frameI,int(y-yHalfWin),int(y+yHalfWin),int(x-xHalfWin),int(x+xHalfWin))
            probList.append(getProb(mse(part,template),sMSE))
            if(probList[i]>maxi):
                maxi=probList[i]
                bestPart=part

        probList=np.asarray(probList)

        probList=probList/probList.sum(0)
        
        template=(1-alpha)*template+bestPart
        
        
        plotImageParticles(frameI,"Frame "+str(j)+" of pres debate with preds",particlesX, particlesY,yHalfWin,xHalfWin,probList)
        display.clear_output(wait=True)
        
        particlesX,particlesY=resampleDiffuse(particlesX,particlesY,probList)

        is_capturing, frame = vc.read()
        j+=1
